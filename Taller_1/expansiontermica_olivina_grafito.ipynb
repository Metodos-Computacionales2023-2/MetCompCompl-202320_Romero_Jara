# %%
from expansiontermicamineral import ExpansionTermicaMineral
import numpy as np

# %%
clase = ExpansionTermicaMineral('olivino',6.5,True,'#9ab973','(FeMg)2SiO4','NO METÁLICO',3.9,'ORTORRÓMBICO', 'olivine_angel_2017.csv')
info = clase.coeficiente_de_expansion()
print('El coeficiente de expansión térmica del Olivino es ' + str((info[0])))
# Out:
# El coeficiente de expansión térmica del Olivino es 2.8605900110854376e-05

# %%
clase2 = ExpansionTermicaMineral('grafito',1.5,False,'#5f6168','C','METÁLICO',2.2,'HEXAGONAL', 'graphite_mceligot_2016.csv')
info2 = clase2.coeficiente_de_expansion()
print('El coeficiente de expansión térmica del Grafito es ' + str((info2[0])))
# Out:
# El coeficiente de expansión térmica del Grafito es 1.6672965341257406e-05
